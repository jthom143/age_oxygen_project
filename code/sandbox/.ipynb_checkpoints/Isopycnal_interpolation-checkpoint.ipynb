# %% [markdown]
# ###### Load Packages

# %%
import iris 
import numpy as np
import matplotlib.pyplot as plt
import gsw
import scipy.interpolate as interp
import iris.quickplot as qplt
from numba import jit
import seaborn as sns

# %%
import sys
sys.path.append('/RESEARCH/paper_ocean_heat_carbon/code/python')
import colormaps as cmaps

# %%
# %matplotlib inline

# %% [markdown]
# ###### Load Data

# %%
PATH = '/RESEARCH/chapter3/data/newCO2_control_800/'
o2 = iris.load_cube(PATH+'o2.nc')
age = iris.load_cube(PATH+'residency_age_surface.nc')
temp = iris.load_cube(PATH+'temp.nc')
salt = iris.load_cube(PATH+'salt.nc')
sigma0 = iris.load_cube(PATH+'/derived/sigma0.nc')

# %%
age.coord('Time').rename('time')
o2 = o2[-500:]

# %% [markdown]
# ###### Calculate Potential Density

# %%
# CT = temp.data
# SA = salt.data

# sigma0 = gsw.sigma0(SA, CT)
# sigma0 = iris.cube.Cube(sigma0, long_name = 'Potential Density', units = 'kg m^-3',
#     dim_coords_and_dims = [(temp.coord('time'), 0), (temp.coord('tcell pstar'), 1),
#     (temp.coord('latitude'), 2), (temp.coord('longitude'), 3)])

# %%
# iris.save(sigma0, PATH+'/derived/sigma0.nc')

# %% [markdown]
# ###### Interpolate to find the depth of the 26 isopycnal

# %%
sigma_data = sigma0[0, :, :, 40].data
lons = sigma0.coord('longitude').points
lats = sigma0.coord('latitude').points
depth = sigma0.coord('tcell pstar').points

depth26 = np.ones((500,80,120)) * np.nan
for t in range(0,500):
    for y in range(0, len(lons)):
        for x in range(0, len(lats)):
            f = interp.interp1d(sigma0[t,:,x,y].data, depth, bounds_error=False)
            depth26[t,x,y] = f(26.0)

plt.figure(figsize=(10,8))
plt.ylim([0, 500])
qplt.contourf(sigma0[0, :, :, 40], 20, cmap = 'jet')
plt.plot(lats, depth26[:,40])
CS = plt.contour(lats, depth, sigma0[0, :, :, 40].data, colors='k', levels=[26])
plt.clabel(CS, fontsize=9, inline=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-9facc4e51a58> in <module>()
#       8     for y in range(0, len(lons)):
#       9         for x in range(0, len(lats)):
# ---> 10             f = interp.interp1d(sigma0[t,:,x,y].data, depth, bounds_error=False)
#      11             depth26[t,x,y] = f(26.0)
#      12
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/iris/cube.pyc in data(self)
#    1681         if not isinstance(data, np.ndarray):
#    1682             try:
# -> 1683                 data = data.masked_array()
#    1684             except MemoryError:
#    1685                 msg = "Failed to create the cube's data as there was not" \
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/Biggus-0.10.0-py2.7.egg/biggus/__init__.pyc in masked_array(self)
#    1328
#    1329     def masked_array(self):
# -> 1330         array = self._apply_keys()
#    1331         # We want the shape of the result to match the shape of the
#    1332         # Array, so where we've ended up with an array-scalar,
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/Biggus-0.10.0-py2.7.egg/biggus/__init__.pyc in _apply_keys(self)
#    1414     """
#    1415     def _apply_keys(self):
# -> 1416         array = self.concrete.__getitem__(self._keys)
#    1417         return array
#    1418
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/iris/fileformats/netcdf.pyc in __getitem__(self, keys)
#     378
#     379     def __getitem__(self, keys):
# --> 380         dataset = netCDF4.Dataset(self.path)
#     381         try:
#     382             variable = dataset.variables[self.variable_name]
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/netCDF4/_netCDF4.so in netCDF4._netCDF4.Dataset.__init__ (netCDF4/_netCDF4.c:9801)()
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/netCDF4/_netCDF4.so in netCDF4._netCDF4._get_types (netCDF4/_netCDF4.c:5695)()
#
# /Users/jordanthomas/anaconda/lib/python2.7/collections.pyc in __init__(*args, **kwds)
#      67             root[:] = [root, root, None]
#      68             self.__map = {}
# ---> 69         self.__update(*args, **kwds)
#      70
#      71     def __setitem__(self, key, value, dict_setitem=dict.__setitem__):
#
# /Users/jordanthomas/anaconda/lib/python2.7/_abcoll.pyc in update(*args, **kwds)
#     546             pass
#     547
# --> 548     def update(*args, **kwds):
#     549         ''' D.update([E, ]**F) -> None.  Update D from mapping/iterable E and F.
#     550             If E present and has a .keys() method, does:     for k in E: D[k] = E[k]
#
# KeyboardInterrupt:

# %%
plt.figure(figsize = (10,6))
clevs = np.arange(0, 550, 50)
plt.contourf(lons, lats, depth26[0,:,:], clevs, cmap = cmaps.viridis, extend = 'max')
plt.colorbar()
plt.title('Depth of $\sigma_{\Theta}$=26.0')

# %%
age26 = np.ones((500, 80,120)) * np.nan
for t in range(0, 500):
    for y in range(0, len(lons)):
        for x in range(0, len(lats)):
            f = interp.interp1d(depth, age[t,:,x,y].data, bounds_error=False)
            age26[t,x,y] = f(depth26[t,x,y])

# %%
plt.figure(figsize = (10,6))
clevs = np.arange(0, 320, 20)
plt.contourf(lons, lats, age26[0,:,:], clevs, cmap = cmaps.viridis, extend = 'max')
plt.colorbar()
plt.title('age on $\sigma_{\Theta}$=26.0')

# %%
o226 = np.ones((500,80,120)) * np.nan
for t in range(0,500):
    for y in range(0, len(lons)):
        for x in range(0, len(lats)):
            f = interp.interp1d(depth, o2[t,:,x,y].data, bounds_error=False)
            o226[t,x,y] = f(depth26[t,x,y])

# %%
plt.figure(figsize = (10,6))
clevs = np.arange(0, 320, 20)
plt.contourf(lons, lats, o226[0,:,:]*1e6, clevs, cmap = cmaps.viridis, extend = 'max')
plt.colorbar()
plt.title('O2 on $\sigma_{\Theta}$=26.0')

# %%
o2_26_cube = iris.cube.Cube(o226,
                      dim_coords_and_dims=[(o2.coord('time'), 0), (o2.coord('latitude'), 1), (o2.coord('longitude'), 2)])

age_26_cube = iris.cube.Cube(age26,
                      dim_coords_and_dims=[(o2.coord('time'), 0), (o2.coord('latitude'), 1), (o2.coord('longitude'), 2)])

# %%
import iris.analysis.stats
correlation = iris.analysis.stats.pearsonr(age_26_cube, o2_26_cube, corr_coords='time')
# Out:
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/iris/coords.py:992: UserWarning: Collapsing a non-contiguous coordinate. Metadata may not be fully descriptive for 'latitude'.
#   warnings.warn(msg.format(self.name()))
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/iris/coords.py:992: UserWarning: Collapsing a non-contiguous coordinate. Metadata may not be fully descriptive for 'longitude'.
#   warnings.warn(msg.format(self.name()))

# %%
plt.figure(figsize = (10,6))
clevs = np.arange(0, 320, 20)
plt.contourf(lons, lats, correlation.data, cmap = 'RdBu_r', extend = 'max')
plt.colorbar()
plt.title('O2 on $\sigma_{\Theta}$=26.0')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-7887c8c7e048> in <module>()
#       1 plt.figure(figsize = (10,6))
#       2 clevs = np.arange(0, 320, 20)
# ----> 3 plt.contourf(lons, lats, correlation.data, cmap = 'RdBu_r', extend = 'max')
#       4 plt.colorbar()
#       5 plt.title('O2 on $\sigma_{\Theta}$=26.0')
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in contourf(*args, **kwargs)
#    2716         ax.hold(hold)
#    2717     try:
# -> 2718         ret = ax.contourf(*args, **kwargs)
#    2719         draw_if_interactive()
#    2720     finally:
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in contourf(self, *args, **kwargs)
#    5338             self.cla()
#    5339         kwargs['filled'] = True
# -> 5340         return mcontour.QuadContourSet(self, *args, **kwargs)
#    5341     contourf.__doc__ = mcontour.QuadContourSet.contour_doc
#    5342
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#    1427         are described in QuadContourSet.contour_doc.
#    1428         """
# -> 1429         ContourSet.__init__(self, ax, *args, **kwargs)
#    1430
#    1431     def _process_args(self, *args, **kwargs):
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#     873         self._transform = kwargs.get('transform', None)
#     874
# --> 875         self._process_args(*args, **kwargs)
#     876         self._process_levels()
#     877
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in _process_args(self, *args, **kwargs)
#    1440             self.zmax = args[0].zmax
#    1441         else:
# -> 1442             x, y, z = self._contour_args(args, kwargs)
#    1443
#    1444             _mask = ma.getmask(z)
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in _contour_args(self, args, kwargs)
#    1504             args = args[1:]
#    1505         elif Nargs <= 4:
# -> 1506             x, y, z = self._check_xyz(args[:3], kwargs)
#    1507             args = args[3:]
#    1508         else:
#
# /Users/jordanthomas/anaconda/lib/python2.7/site-packages/matplotlib/contour.pyc in _check_xyz(self, args, kwargs)
#    1538
#    1539         if z.ndim != 2:
# -> 1540             raise TypeError("Input z must be a 2D array.")
#    1541         else:
#    1542             Ny, Nx = z.shape
#
# TypeError: Input z must be a 2D array.
